# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
#easy way
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
#Recommended way of plotting
fig,ax=plt.subplots()
ax.plot(x,y)

# %% [markdown]
# # Matplotlib example workflow:

# %%
# 0. import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. prepare data
x=[1,2,3,4]
y=[11,22,33,44]

# 2. Setup Plot
fig,ax=plt.subplots(figsize=(5,6))

# 3. plot data
ax.plot(x,y)

# 4. customize data
ax.set(title="Simple Plot",
      xlabel="x-axis",
      ylabel="y-axis")
# 5. save and show the whole figure
plt.savefig('figures/sample-plot.png')

# %% [markdown]
# # Scatter Plot and Bar Plot

# %%
# Making figures with NumPy arrays,
#Create some data
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data
fig,ax=plt.subplots(figsize=(5,4))
ax.plot(x,x**2)# this is called as line plot

# %%
#use some data to make a scatter
fig,ax=plt.subplots(figsize=(5,4))
ax.scatter(x,np.exp(x))# creating an exponential graph

# %%
#another scatter plot with sin function
fig,ax=plt.subplots(figsize=(5,4))
plt.scatter(x,np.sin(x))

# %%
## Bar Plot
# Bar plot using python dictionary
#make a plot from dictionary

nut_butter_prices={"Almond Butter":10,
                  "Peanut Butter":8,
                  "Cashew Butter":12}
fig,ax=plt.subplots(figsize=(5,4))
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax.set(title="Dan's Nut Butter Store",
      ylabel="Price ($)")
# Out:
# [Text(0, 0.5, 'Price ($)'), Text(0.5, 1.0, "Dan's Nut Butter Store")]

# %%
## Horizontal bar creation,
fig,ax=plt.subplots(figsize=(5,4))
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))#It has to be turned into a list.
# Out:
# <BarContainer object of 3 artists>

# %%
# Plotting histogram,
#make some data
x=np.random.randn(1000)#The numpy.random.randn() function creates an array of specified shape and fills it with random values
fig,ax=plt.subplots(figsize=(5,4))
ax.hist(x)
# Out:
# (array([  6.,  13.,  62., 140., 236., 239., 171.,  97.,  29.,   7.]),
#  array([-3.23256543, -2.61789797, -2.0032305 , -1.38856304, -0.77389557,
#         -0.15922811,  0.45543936,  1.07010682,  1.68477429,  2.29944175,
#          2.91410922]),
#  <a list of 10 Patch objects>)

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2020",periods=1000))
ts=ts.cumsum()
ts.plot()

# %% [markdown]
# ## Importing csv file and performing visualizations

# %%
df=pd.read_csv('car-sales.csv')

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Replacing the expressions
df["Price"]=df["Price"].str.replace('$','')

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   4,000.00
# 1   Honda    Red          87899      4   5,000.00
# 2  Toyota   Blue          32549      3   7,000.00
# 3     BMW  Black          11179      5  22,000.00
# 4  Nissan  White         213095      4   3,500.00
# 5  Toyota  Green          99213      4   4,500.00
# 6   Honda   Blue          45698      4   7,500.00
# 7   Honda   Blue          54738      4   7,000.00
# 8  Toyota  White          60000      4   6,250.00
# 9  Nissan  White          31600      4   9,700.00

# %%
df["Price"]=df["Price"].str[:-2]
df
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   4,000.0
# 1   Honda    Red          87899      4   5,000.0
# 2  Toyota   Blue          32549      3   7,000.0
# 3     BMW  Black          11179      5  22,000.0
# 4  Nissan  White         213095      4   3,500.0
# 5  Toyota  Green          99213      4   4,500.0
# 6   Honda   Blue          45698      4   7,500.0
# 7   Honda   Blue          54738      4   7,000.0
# 8  Toyota  White          60000      4   6,250.0
# 9  Nissan  White          31600      4   9,700.0

# %%
#Converting the price column to a numeric value. This example includes to keep the data with decimal points.
df["Price"]=df["Price"].str.replace('[\$\,]|\.\d*','').astype(float)

# %%
# Adding date column
df["Sale Date"]=pd.date_range("1/1/2020",periods=len(df))
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date
# 0  Toyota  White         150043      4   4000.0 2020-01-01
# 1   Honda    Red          87899      4   5000.0 2020-01-02
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03
# 3     BMW  Black          11179      5  22000.0 2020-01-04
# 4  Nissan  White         213095      4   3500.0 2020-01-05
# 5  Toyota  Green          99213      4   4500.0 2020-01-06
# 6   Honda   Blue          45698      4   7500.0 2020-01-07
# 7   Honda   Blue          54738      4   7000.0 2020-01-08
# 8  Toyota  White          60000      4   6250.0 2020-01-09
# 9  Nissan  White          31600      4   9700.0 2020-01-10

# %%
#Appling Cumulative summation
df["Total Sales"]=df["Price"].cumsum().astype(int)
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01         4000
# 1   Honda    Red          87899      4   5000.0 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03        16000
# 3     BMW  Black          11179      5  22000.0 2020-01-04        38000
# 4  Nissan  White         213095      4   3500.0 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500.0 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500.0 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000.0 2020-01-08        60500
# 8  Toyota  White          60000      4   6250.0 2020-01-09        66750
# 9  Nissan  White          31600      4   9700.0 2020-01-10        76450

# %%
#lets plot the total/cumsum sales
#line plot
df.plot(x="Sale Date",y="Total Sales")
plt.ylabel("Price ($)")
# Out:
# Text(0, 0.5, 'Price ($)')

# %%
#reassign price column to int
df["Price"]=df["Price"].astype(int)
#scatter plot
df.plot(x="Odometer (KM)", y="Price", kind="scatter")

# %%
# Car graph from the imported data frame,
df.plot(x="Make", y="Odometer (KM)", kind="bar")

# %%
#histogram
df["Odometer (KM)"].plot.hist()
#df["Odometer (KM)"].hist() #another way

# %%
df["Total Sales"].plot(kind="bar",color=["salmon"])

# %%
heart_disease=pd.read_csv('heart_disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over_50=heart_disease[heart_disease['age']>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50['age'].plot.hist()

# %%
##see the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#To update the default style,
plt.style.use('seaborn-whitegrid')
df['Price'].plot()

# %%
#seaborn style
plt.style.use('seaborn')
df['Price'].plot()
